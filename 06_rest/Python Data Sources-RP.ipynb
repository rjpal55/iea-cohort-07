# %% [markdown]
# # Getting Data into Python

# %% [markdown]
# ## Agenda
# * Network / HTTP concepts
# * REST API concepts
# * Calling APIs with Python
# * Web Scraping with BeautifulSoup
# * Connecting to Databases
# * Other data sources

# %% [markdown]
# ## Getting Data from the Web

# %% [markdown]
# ## Network Fundamentals
# * Networks communicate messages between **clients** and **servers**
# * Many different protocols throughout history
# * Dominant protocol today is **TCP/IP**
# * Web requests use **HyperText Transfer Protocol (HTTP)**

# %% [markdown]
# # OSI Network Model![OSI Model](images/osi.png)

# %% [markdown]
# ### HyperText Transfer Protocol
# - This is the way our web browsers work!
# - Replaced older network protocols like gopher
# - Development of HTTP was initiated by Tim Berners-Lee at CERN in 1989
# - HTTP is a text-based protocol (not binary)
# - HTTP is *stateless* - every request must contain all contextual info!
# - HTTPS is simply HTTP over SSL (Secure Socket Layer) so that requests and responses are encrypted from client to server and back (but beware of DNS leaks!)
# - HTTP 1.1 Specification (good luck!): https://tools.ietf.org/html/rfc7231

# %% [markdown]
# # HTTP Request
# ![Network Request](images/client_server.png)

# %%
# !curl -v https://xkcd.com/
# Out:
# *   Trying 151.101.0.67:443...
# * Connected to xkcd.com (151.101.0.67) port 443 (#0)
# * ALPN, offering h2
# * ALPN, offering http/1.1
# * Cipher selection: ALL:!EXPORT:!EXPORT40:!EXPORT56:!aNULL:!LOW:!RC4:@STRENGTH
# * successfully set certificate verify locations:
# *  CAfile: /etc/pki/tls/certs/ca-bundle.crt
# *  CApath: none
# * TLSv1.2 (OUT), TLS header, Certificate Status (22):
# * TLSv1.2 (OUT), TLS handshake, Client hello (1):
# * TLSv1.2 (IN), TLS handshake, Server hello (2):
# * TLSv1.2 (IN), TLS handshake, Certificate (11):
# * TLSv1.2 (IN), TLS handshake, Server key exchange (12):
# * TLSv1.2 (IN), TLS handshake, Server finished (14):
# * TLSv1.2 (OUT), TLS handshake, Client key exchange (16):
# * TLSv1.2 (OUT), TLS change cipher, Change cipher spec (1):
# * TLSv1.2 (OUT), TLS handshake, Finished (20):
# * TLSv1.2 (IN), TLS change cipher, Change cipher spec (1):
# * TLSv1.2 (IN), TLS handshake, Finished (20):
# * SSL connection using TLSv1.2 / ECDHE-RSA-AES128-GCM-SHA256
# * ALPN, server accepted to use http/1.1
# * Server certificate:
# *  subject: CN=xkcd.com
# *  start date: Dec 24 20:45:39 2021 GMT
# *  expire date: Jan 25 20:45:38 2023 GMT
# *  subjectAltName: host "xkcd.com" matched cert's "xkcd.com"
# *  issuer: C=BE; O=GlobalSign nv-sa; CN=GlobalSign Atlas R3 DV TLS CA H2 2021
# *  SSL certificate verify ok.
# > GET / HTTP/1.1
# > Host: xkcd.com
# > User-Agent: curl/7.79.1
# > Accept: */*
# >
# * Mark bundle as not supporting multiuse
# < HTTP/1.1 200 OK
# < Connection: keep-alive
# < Content-Length: 7830
# < Server: nginx
# < Content-Type: text/html; charset=UTF-8
# < Last-Modified: Fri, 13 May 2022 13:55:50 GMT
# < ETag: "627e6366-1e96"
# < Expires: Fri, 13 May 2022 14:01:44 GMT
# < Cache-Control: max-age=300
# < Via: 1.1 varnish, 1.1 varnish
# < Accept-Ranges: bytes
# < Date: Mon, 16 May 2022 15:58:58 GMT
# < Age: 29
# < X-Served-By: cache-dfw18622-DFW, cache-iad-kiad7000045-IAD
# < X-Cache: HIT, HIT
# < X-Cache-Hits: 1, 1
# < X-Timer: S1652716739.736644,VS0,VE1
# < Vary: Accept-Encoding
# <
# <!DOCTYPE html>
# <html>
# <head>
# <link rel="stylesheet" type="text/css" href="/s/7d94e0.css" title="Default"/>
# <title>xkcd: Crêpe</title>
# <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
# <link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>
# <link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>
# <link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>
# <link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>
# <script type="text/javascript" src="/s/b66ed7.js" async></script>
# <script type="text/javascript" src="/s/1b9456.js" async></script>
#
# <meta property="og:site_name" content="xkcd">
#
# <meta property="og:title" content="Crêpe">
# <meta property="og:url" content="https://xkcd.com/2619/">
# <meta property="og:image" content="https://imgs.xkcd.com/comics/crepe_2x.png">
# <meta name="twitter:card" content="summary_large_image">
#
# </head>
# <body>
# <div id="topContainer">
# <div id="topLeft">
# <ul>
# <li><a href="/archive">Archive</a></li>
# <li><a href="https://what-if.xkcd.com">What If?</a></li>
# <li><a href="https://blag.xkcd.com">Blag</a></li>
# <li><a rel="author" href="/about">About</a></li>
# <li><a href="/atom.xml">Feed</a>&bull;<a href="/newsletter/">Email</a></li>
# <li><a href="https://twitter.com/xkcd/">TW</a>&bull;<a href="https://www.facebook.com/TheXKCD/">FB</a>&bull;<a href="https://www.instagram.com/xkcd/">IG</a></li>
# <li><a href="/books/">-Books-</a></li>
# <li><a href="/what-if-2/">What If? 2</a></li>
# <li><a href="/what-if/">WI?</a>&bull;<a href="/thing-explainer/">TE</a>&bull;<a href="/how-to/">HT</a></li>
# </ul>
# </div>
# <div id="topRight">
# <div id="masthead">
# <span><a href="/"><img src="/s/0b7742.png" alt="xkcd.com logo" height="83" width="185"/></a></span>
# <span id="slogan">A webcomic of romance,<br/> sarcasm, math, and language.</span>
# </div>
# <div id="news">
# <div id="xkcdNews">
# <div id="countdown" style="float: right; margin-right: 25px; width: 160px; height: 100px; position: relative;"><a style="display: flex;" href="https://xkcd.com/what-if-2/"><img alt="" style="width: 160px; height: 100px;" src="https://xkcd.com/s/5bef6b.png"><span style="position: absolute; left: 50%; top: 50%; transform: translate(-50%, -50%); padding: 0px 8px; color: black; font-family: xkcd-Regular-v3; font-size: 20px; font-variant: small-caps; letter-spacing: 1px; white-space: nowrap; background: white none repeat scroll 0% 0%; border-radius: 99px; display: none;"></span></a></div>
# <em>What If? 2: Additional Serious Scientific Answers to Absurd Hypothetical Questions</em> comes out 9/13. Preorder <a href="https://xkcd.com/what-if-2">here!</a>
# </div>
# <script>
# var client = new XMLHttpRequest();
# client.open("GET", "//c.xkcd.com/xkcd/news", true);
# client.send();
# client.onreadystatechange = function() {
#   if(client.readyState == 4 && client.status == 200) {
#     document.getElementById("xkcdNews").innerHTML = client.responseText;
#   }
# }
# </script>
#
# </div>
# </div>
# <div id="bgLeft" class="bg box"></div>
# <div id="bgRight" class="bg box"></div>
# </div>
# <div id="middleContainer" class="box">
#
# <div id="ctitle">Crêpe</div>
# <ul class="comicNav">
# <li><a href="/1/">|&lt;</a></li>
# <li><a rel="prev" href="/2618/" accesskey="p">&lt; Prev</a></li>
# <li><a href="//c.xkcd.com/random/comic/">Random</a></li>
# <li><a rel="next" href="#" accesskey="n">Next &gt;</a></li>
# <li><a href="/">&gt;|</a></li>
# </ul>
# <div id="comic">
# <img src="//imgs.xkcd.com/comics/crepe.png" title="A medicine that makes you put two dots over your letters more often is a diäretic." alt="Crêpe" srcset="//imgs.xkcd.com/comics/crepe_2x.png 2x" style="image-orientation:none" />
# </div>
# <ul class="comicNav">
# <li><a href="/1/">|&lt;</a></li>
# <li><a rel="prev" href="/2618/" accesskey="p">&lt; Prev</a></li>
# <li><a href="//c.xkcd.com/random/comic/">Random</a></li>
# <li><a rel="next" href="#" accesskey="n">Next &gt;</a></li>
# <li><a href="/">&gt;|</a></li>
# </ul>
# <br />
# Permanent link to this comic: <a href="https://xkcd.com/2619">https://xkcd.com/2619/</a><br />
# Image URL (for hotlinking/embedding): <a href= "https://imgs.xkcd.com/comics/crepe.png">https://imgs.xkcd.com/comics/crepe.png</a>
#
# <div id="transcript" style="display: none"></div>
# </div>
# <div id="bottom" class="box">
# <img src="//imgs.xkcd.com/s/a899e84.jpg" width="520" height="100" alt="Selected Comics" usemap="#comicmap"/>
# <map id="comicmap" name="comicmap">
# <area shape="rect" coords="0,0,100,100" href="/150/" alt="Grownups"/>
# <area shape="rect" coords="104,0,204,100" href="/730/" alt="Circuit Diagram"/>
# <area shape="rect" coords="208,0,308,100" href="/162/" alt="Angular Momentum"/>
# <area shape="rect" coords="312,0,412,100" href="/688/" alt="Self-Description"/>
# <area shape="rect" coords="416,0,520,100" href="/556/" alt="Alternative Energy Revolution"/>
# </map>
# <br />
# <a href="//xkcd.com/1732/"><img border=0 src="//imgs.xkcd.com/s/temperature.png" width="520" height="100" alt="Earth temperature timeline"></a>
# <br />
# <div>
# <!--
# Search comic titles and transcripts:
# <script type="text/javascript" src="//www.google.com/jsapi"></script>
# <script type="text/javascript">google.load('search', '1');google.setOnLoadCallback(function() {google.search.CustomSearchControl.attachAutoCompletion('012652707207066138651:zudjtuwe28q',document.getElementById('q'),'cse-search-box');});</script>
# <form action="//www.google.com/cse" id="cse-search-box">
# <div>
# <input type="hidden" name="cx" value="012652707207066138651:zudjtuwe28q"/>
# <input type="hidden" name="ie" value="UTF-8"/>
# <input type="text" name="q" id="q" size="31"/>
# <input type="submit" name="sa" value="Search"/>
# </div>
# </form>
# <script type="text/javascript" src="//www.google.com/cse/brand?form=cse-search-box&amp;lang=en"></script>
# -->
# <a href="/rss.xml">RSS Feed</a> - <a href="/atom.xml">Atom Feed</a> - <a href="/newsletter/">Email</a>
# </div>
# <br />
# <div id="comicLinks">
# Comics I enjoy:<br/>
#         <a href="http://threewordphrase.com/">Three Word Phrase</a>,
#         <a href="https://www.smbc-comics.com/">SMBC</a>,
#         <a href="https://www.qwantz.com">Dinosaur Comics</a>,
#         <a href="https://oglaf.com/">Oglaf</a> (nsfw),
#         <a href="https://www.asofterworld.com">A Softer World</a>,
#         <a href="https://buttersafe.com/">Buttersafe</a>,
#         <a href="https://pbfcomics.com/">Perry Bible Fellowship</a>,
#         <a href="https://questionablecontent.net/">Questionable Content</a>,
#         <a href="http://www.buttercupfestival.com/">Buttercup Festival</a>,
#         <a href="https://www.mspaintadventures.com/">Homestuck</a>,
# 	<a href="https://www.jspowerhour.com/">Junior Scientist Power Hour</a>
# </div>
# <br />
# <div id="comicLinks">
# Other things:<br/>
#         <a href="https://medium.com/civic-tech-thoughts-from-joshdata/so-you-want-to-reform-democracy-7f3b1ef10597">Tips on technology and government</a>,<br />
#         <a href="https://www.nytimes.com/interactive/2017/climate/what-is-climate-change.html">Climate FAQ</a>,
# 	<a href="https://twitter.com/KHayhoe">Katharine Hayhoe</a>
# </div>
# <br />
# <center>
# <div id="footnote" style="width:70%">xkcd.com is best viewed with Netscape Navigator 4.0 or below on a Pentium 3&plusmn;1 emulated in Javascript on an Apple IIGS<br />at a screen resolution of 1024x1. Please enable your ad blockers, disable high-heat drying, and remove your device<br />from Airplane Mode and set it to Boat Mode. For security reasons, please leave caps lock on while browsing.</div>
# </center>
# <div id="licenseText">
# <p>
# This work is licensed under a
# <a href="https://creativecommons.org/licenses/by-nc/2.5/">Creative Commons Attribution-NonCommercial 2.5 License</a>.
# </p><p>
# This means you're free to copy and share these comics (but not to sell them). <a rel="license" href="/license.html">More details</a>.</p>
# </div>
# </div>
# </body>
# <!-- Layout by Ian Clasbey, davean, and chromakode -->
# </html>
#
# * Connection #0 to host xkcd.com left intact

# %% [markdown]
# ### HTTP Request components
# - URL
# - Verb
# - Headers (optional)
# - Body (optional)
#
# ### HTTP Response components
# - Status Code
# - Headers (optional)
# - Body (optional)

# %% [markdown]
# ### HTTP Status Code Categories
# - 1xx Informational
# - 2xx Success
# - 3xx Redirection
# - 4xx Client Error / Invalid Request (User's Fault)
# - 5xx Server Error (Server's Fault)

# %% [markdown]
# ### Common REST Status Code meanings
#
# #### 2xx
# - 200 "OK" - General Success (often overused)
# - 201 "Created" - Created a new resource on the server (usually from POST)
# - 202 "Accepted" - Request was accepted, but may not yet be completed (long process)
#
# #### 3xx
# - 301 "Moved Permanently" - URL for a resource was changed
# - 302 "Found" - The resource was found at another URL (temporary redirect, "canonical" URLs)
# - 303 "See Other" - Often the same as a 302
# - 304 "Not Modified" - Resource has not changed since the last request, use cached value
#
# #### 4xx
# - 400 "Bad Request" - Malformed requests, bad parameters, invalid formats
# - 401 "Unauthorized" - The resource requires credentials to access (i.e. requires login)
# - 403 "Forbidden" - The client does not have permission to access the resource
# - 404 "Not Found" - No resource located at this URL
# - 409 "Conflict" - Cannot edit the resource due to a conflict
# - 429 "Too Many Requests" - Used for API rate limiting
#
# #### 5xx
# - 500 "Internal Server Error" - Generic, "something went wrong" message, might indicate a bug in server code.
# - 502 "Bad Gateway" - A load balancer or proxy got no response from a webserver
# - 503 "Service Unavailable" - The server is overloaded, or down for maintenance, etc.

# %% [markdown]
# ## API (Application Programming Interface)
# * Interface specifically design for code to interact with
# * No one specification for APIs - it depends on who authors it
# * Network APIs can be binary or text, public or private, synchronous or asynchrous (and more)
# * HTTP-based APIs ("web services") have many forms - WDSL, SOAP, proprietary

# %% [markdown]
# ## REST APIs
# * __RE__presentational __S__tate __T__ransfer
# * Aims to use HTTP "as intended" to build the API
# * Familiar tools:
#     * URI (URL) uniquely identifies a "resource"
#     * HTTP verbs define what action is intended
#     * Status codes (200, 404, 500, etc) communicate results
#     * Headers provide extra info (data formats, encoding, compression)
# * Not a standard!
#     * Any data format - JSON, XML, CSV, plain text
#     * Any "resource" - Author's choice (read the docs!)

# %% [markdown]
# | HTTP Method | Description | "CRUD" Action | Request Body | Response Body | Only Reads | Idempotent | Cacheable |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | **GET** | Retrieve a resource | Read | Optional | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> |
# | **HEAD** | Retrieve headers for a resource | Read | Optional | <span style="color: red;">No</span> | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> |
# | **POST** | Post data for a resource | Create | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: red;">No</span> | <span style="color: red;">No</span> | <span style="color: green;">Yes</span> |
# | **PUT** | Post data (replace) and existing resource | Update | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: red;">No</span> | <span style="color: green;">Yes</span> | <span style="color: red;">No</span> |
# | **DELETE** | Delete a resource | Delete | Optional | <span style="color: green;">Yes</span> | <span style="color: red;">No</span> | <span style="color: green;">Yes</span> | <span style="color: red;">No</span> |
# | **CONNECT** | Convert connection to a tunnel | N/A | Optional | <span style="color: green;">Yes</span> | <span style="color: red;">No</span> | <span style="color: red;">No</span> | <span style="color: red;">No</span> |
# | **OPTIONS** | Request the supported methods for a resource | N/A | Optional | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: red;">No</span> |
# | **TRACE** | Echo a client request for testing | N/A | <span style="color: red;">No</span> | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: red;">No</span> |
# | **PATCH** | Update a resource with partial data | Update | <span style="color: green;">Yes</span> | <span style="color: green;">Yes</span> | <span style="color: red;">No</span> | <span style="color: red;">No</span> | <span style="color: red;">No</span> |

# %% [markdown]
# ### Request / Response Bodies
# - The HTTP Specification does not address the format of the body
# - Requests and Responses can be sent in any format that both support
# - Common formats:  HTML, plain text, JSON, XML, YAML, etc.
# - See the **Accept** and **Content-Type** headers (and the API docs!)

# %% [markdown]
# ### Request / Response Headers
#
# - Headers are just key/value pairs (remind you of anything?)
# - Values are always just text
# - Many standard headers, but some APIs may add custom ones
#
# #### Common Headers
#
# - **Location:** Specify location of requested resource
#   Example: `Location: http://www.google.com`
# - **Content-Type:** Format of the request body
#   Example: `Content-Type: application/json`
# - **Accept:** Tells the server which body format to return
#   Example: `Accept: application/xml`
# - **User Agent:** Information about the application sending the request
#   Example: `User-Agent: curl/7.58.0`
# - **Cookies:** Misc key-value pairs stored at the client and resent on each request
#   Example: `set-cookie: NID=212=v2D4SUIJMhZuI9NWCSmaxWXm0KP01ydT-3ptgttKK3E0dn8_CoixMhU3ql1JotoZ79UbRTDThg7c9APBoipLJjSdLv0H4CLmz7ozxzzqf57Pel4bohmWDpuFcBYT7_h58lkm4-x3OPnZo09bxOJw-LJQGWkurHOnJHioz21Sd30; expires=Sat, 02-Oct-2021 12:09:52 GMT; path=/; domain=.google.com; HttpOnly`

# %% [markdown]
# ## Lab:  HTTP Requests
# Using the `curl` Linux command line tool (install it with yum if you don't have it), make some web requests to sites you know.  Use the `-v` option (verbose) to see the details of the request and response, and identify the HTTP Method, URL, and Headers.
#
# **Bonus:** Using the curl man page (or web search), find out how to send different HTTP Methods with `curl` and try a few out, even those you know may not work, to see what responses you get.

# %% [markdown]
# ## REST APIs in Python

# %% [markdown]
# ## To talk to a REST API in Python, we need to:
# * Make a web request
# * Parse the information it gives us
# * Luckily, Python gives us both in the standard library!

# %% [markdown]
# ## urllib: Package of modules for making and dealing with HTTP

# %%
from urllib.request import urlopen
SECRET_KEY = '1d8c58ed1d54f96f939e706c788650f1'

lat, long = (33.8840,-84.5144)  # Smyrna, GA

url = 'https://api.darksky.net/forecast/{key}/{lat},{long}'.format(
    key=SECRET_KEY, lat=lat, long=long)
response = urlopen(url)  # Defaults to a GET request
# Returns a file-like Response object, so we can read it just like File I/O
print(response)
print(dir(response))
# Out:
# <http.client.HTTPResponse object at 0x7fdb65dacbd0>
# ['__abstractmethods__', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_abc_impl', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_check_close', '_close_conn', '_get_chunk_left', '_method', '_peek_chunked', '_read1_chunked', '_read_and_discard_trailer', '_read_next_chunk_size', '_read_status', '_readall_chunked', '_readinto_chunked', '_safe_read', '_safe_readinto', 'begin', 'chunk_left', 'chunked', 'close', 'closed', 'code', 'debuglevel', 'detach', 'fileno', 'flush', 'fp', 'getcode', 'getheader', 'getheaders', 'geturl', 'headers', 'info', 'isatty', 'isclosed', 'length', 'msg', 'peek', 'read', 'read1', 'readable', 'readinto', 'readinto1', 'readline', 'readlines', 'reason', 'seek', 'seekable', 'status', 'tell', 'truncate', 'url', 'version', 'will_close', 'writable', 'write', 'writelines']

# %%
forecast_data = response.read()
print(forecast_data)
# Out:
# b'{"latitude":33.884,"longitude":-84.5144,"timezone":"America/New_York","currently":{"time":1652802910,"summary":"Clear","icon":"clear-day","nearestStormDistance":78,"nearestStormBearing":169,"precipIntensity":0,"precipProbability":0,"temperature":77.35,"apparentTemperature":77.35,"dewPoint":51.6,"humidity":0.41,"pressure":1018,"windSpeed":3.26,"windGust":5.74,"windBearing":49,"cloudCover":0.07,"uvIndex":8,"visibility":10,"ozone":325.8},"minutely":{"summary":"Clear for the hour.","icon":"clear-day","data":[{"time":1652802900,"precipIntensity":0,"precipProbability":0},{"time":1652802960,"precipIntensity":0,"precipProbability":0},{"time":1652803020,"precipIntensity":0,"precipProbability":0},{"time":1652803080,"precipIntensity":0,"precipProbability":0},{"time":1652803140,"precipIntensity":0,"precipProbability":0},{"time":1652803200,"precipIntensity":0,"precipProbability":0},{"time":1652803260,"precipIntensity":0,"precipProbability":0},{"time":1652803320,"precipIntensity":0,"precipProbability":0},{"time":1652803380,"precipIntensity":0,"precipProbability":0},{"time":1652803440,"precipIntensity":0,"precipProbability":0},{"time":1652803500,"precipIntensity":0,"precipProbability":0},{"time":1652803560,"precipIntensity":0,"precipProbability":0},{"time":1652803620,"precipIntensity":0,"precipProbability":0},{"time":1652803680,"precipIntensity":0,"precipProbability":0},{"time":1652803740,"precipIntensity":0,"precipProbability":0},{"time":1652803800,"precipIntensity":0,"precipProbability":0},{"time":1652803860,"precipIntensity":0,"precipProbability":0},{"time":1652803920,"precipIntensity":0,"precipProbability":0},{"time":1652803980,"precipIntensity":0,"precipProbability":0},{"time":1652804040,"precipIntensity":0,"precipProbability":0},{"time":1652804100,"precipIntensity":0,"precipProbability":0},{"time":1652804160,"precipIntensity":0,"precipProbability":0},{"time":1652804220,"precipIntensity":0,"precipProbability":0},{"time":1652804280,"precipIntensity":0,"precipProbability":0},{"time":1652804340,"precipIntensity":0,"precipProbability":0},{"time":1652804400,"precipIntensity":0,"precipProbability":0},{"time":1652804460,"precipIntensity":0,"precipProbability":0},{"time":1652804520,"precipIntensity":0,"precipProbability":0},{"time":1652804580,"precipIntensity":0,"precipProbability":0},{"time":1652804640,"precipIntensity":0,"precipProbability":0},{"time":1652804700,"precipIntensity":0,"precipProbability":0},{"time":1652804760,"precipIntensity":0,"precipProbability":0},{"time":1652804820,"precipIntensity":0,"precipProbability":0},{"time":1652804880,"precipIntensity":0,"precipProbability":0},{"time":1652804940,"precipIntensity":0,"precipProbability":0},{"time":1652805000,"precipIntensity":0,"precipProbability":0},{"time":1652805060,"precipIntensity":0,"precipProbability":0},{"time":1652805120,"precipIntensity":0,"precipProbability":0},{"time":1652805180,"precipIntensity":0,"precipProbability":0},{"time":1652805240,"precipIntensity":0,"precipProbability":0},{"time":1652805300,"precipIntensity":0,"precipProbability":0},{"time":1652805360,"precipIntensity":0,"precipProbability":0},{"time":1652805420,"precipIntensity":0,"precipProbability":0},{"time":1652805480,"precipIntensity":0,"precipProbability":0},{"time":1652805540,"precipIntensity":0,"precipProbability":0},{"time":1652805600,"precipIntensity":0,"precipProbability":0},{"time":1652805660,"precipIntensity":0,"precipProbability":0},{"time":1652805720,"precipIntensity":0,"precipProbability":0},{"time":1652805780,"precipIntensity":0,"precipProbability":0},{"time":1652805840,"precipIntensity":0,"precipProbability":0},{"time":1652805900,"precipIntensity":0,"precipProbability":0},{"time":1652805960,"precipIntensity":0,"precipProbability":0},{"time":1652806020,"precipIntensity":0,"precipProbability":0},{"time":1652806080,"precipIntensity":0,"precipProbability":0},{"time":1652806140,"precipIntensity":0,"precipProbability":0},{"time":1652806200,"precipIntensity":0,"precipProbability":0},{"time":16528062 ...

# %% [markdown]
# ## json: Parsing and creating JSON-formatted data

# %%
import json

msg = json.loads('{"language": "en", "name": "Fred", "color": "blue"}')
print(msg, type(msg))
print(msg['color'])

msg['color'] = 'green'
s = json.dumps(msg)
print(s, type(s))
# Out:
# {'language': 'en', 'name': 'Fred', 'color': 'blue'} <class 'dict'>
# blue
# {"language": "en", "name": "Fred", "color": "green"} <class 'str'>

# %%
forecast = json.loads(forecast_data)
# Depending on the API, this can get really deep!  Consider breaking things down
print(type(forecast))
time = forecast['currently']['time']
temp = forecast['currently']['temperature']
print(time, temp)

today = forecast['daily']['data'][0]

print('Today - High: {high}, Low: {low}'.format(
    high=today['temperatureHigh'], low=today['temperatureLow']))
# Out:
# <class 'dict'>
# 1652802910 77.35
# Today - High: 84.11, Low: 61.59

# %%
from pprint import pprint
pprint(forecast)
# Out:
# {'currently': {'apparentTemperature': 77.35,
#                'cloudCover': 0.07,
#                'dewPoint': 51.6,
#                'humidity': 0.41,
#                'icon': 'clear-day',
#                'nearestStormBearing': 169,
#                'nearestStormDistance': 78,
#                'ozone': 325.8,
#                'precipIntensity': 0,
#                'precipProbability': 0,
#                'pressure': 1018,
#                'summary': 'Clear',
#                'temperature': 77.35,
#                'time': 1652802910,
#                'uvIndex': 8,
#                'visibility': 10,
#                'windBearing': 49,
#                'windGust': 5.74,
#                'windSpeed': 3.26},
#  'daily': {'data': [{'apparentTemperatureHigh': 83.61,
#                      'apparentTemperatureHighTime': 1652820060,
#                      'apparentTemperatureLow': 62.08,
#                      'apparentTemperatureLowTime': 1652867940,
#                      'apparentTemperatureMax': 83.61,
#                      'apparentTemperatureMaxTime': 1652820060,
#                      'apparentTemperatureMin': 56.94,
#                      'apparentTemperatureMinTime': 1652784600,
#                      'cloudCover': 0.05,
#                      'dewPoint': 51.33,
#                      'humidity': 0.51,
#                      'icon': 'clear-day',
#                      'moonPhase': 0.57,
#                      'ozone': 323.7,
#                      'precipIntensity': 0,
#                      'precipIntensityMax': 0,
#                      'precipIntensityMaxTime': 1652778000,
#                      'precipProbability': 0,
#                      'pressure': 1016,
#                      'summary': 'Clear throughout the day.',
#                      'sunriseTime': 1652783820,
#                      'sunsetTime': 1652834100,
#                      'temperatureHigh': 84.11,
#                      'temperatureHighTime': 1652820060,
#                      'temperatureLow': 61.59,
#                      'temperatureLowTime': 1652867940,
#                      'temperatureMax': 84.11,
#                      'temperatureMaxTime': 1652820060,
#                      'temperatureMin': 56.45,
#                      'temperatureMinTime': 1652784600,
#                      'time': 1652760000,
#                      'uvIndex': 10,
#                      'uvIndexTime': 1652809020,
#                      'visibility': 10,
#                      'windBearing': 348,
#                      'windGust': 11.66,
#                      'windGustTime': 1652762340,
#                      'windSpeed': 4.07},
#                     {'apparentTemperatureHigh': 88.42,
#                      'apparentTemperatureHighTime': 1652907300,
#                      'apparentTemperatureLow': 72.19,
#                      'apparentTemperatureLowTime': 1652956560,
#                      'apparentTemperatureMax': 88.42,
#                      'apparentTemperatureMaxTime': 1652907300,
#                      'apparentTemperatureMin': 62.08,
#                      'apparentTemperatureMinTime': 1652867940,
#                      'cloudCover': 0.15,
#                      'dewPoint': 55.17,
#                      'humidity': 0.51,
#                      'icon': 'clear-day',
#                      'moonPhase': 0.61,
#                      'ozone': 318.8,
#                      'precipIntensity': 0,
#                      'precipIntensityMax': 0,
#                      'precipProbability': 0,
#                      'pressure': 1015.8,
#                      'summary': 'Clear throughout the day.',
#                      'sunriseTime': 1652870160,
#                      'sunsetTime': 1652920560,
#                      'temperatureHigh': 88.92,
#                      'temperatureHighTime': 1652907300,
#                      'temperatureLow': 70.76,
#                      'temperatureLowTime': 1652956920,
#                      'temperatureMax': 88.92,
#                      'temperatureMaxTime': 1652907300,
#                      'temperatureMin': 61.59,
#                      'temperatureMinTime': 1652867940,
#                      'time': 1652846400,
#                      'uvIndex': 10,
#                      'uvIndexTime': 1652895240,
#                      'visibility': 10,
#                      'windBearing': 198,
#                      'windGust': 14.4,
#                      'windGustTime': 1652932800,
#                      'windSpeed': 5.03},
#                     {'apparentTemperatureHigh': 93.82,
#                      'apparentTemperatureHighTime': 1652989620,
#                      'apparentTemperatureLow': 72.84,
#                      'apparentTemperatureLowTime': 1653043860,
#                      'apparentTemperatureMax': 93.82,
#                      'apparentTemperatureMaxTime': 1652989620,
#                      'apparentTemperatureMin': 72.19,
#                      'apparentTemperatureMinTime': 1652956560,
#                      'cloudCover': 0.27,
#                      'dewPoint': 66.4,
#                      'humidity': 0.63,
#                      'icon': 'clear-day',
#                      'moonPhase': 0.65,
#                      'ozone': 316.7,
#                      'precipIntensity': 0.0009,
#                      'precipIntensityMax': 0.0053,
#                      'precipIntensityMaxTime': 1652947380,
#                      'precipProbability': 0.12,
#                      'precipType': 'rain',
#                      'pressure': 1012.2,
#                      'summary': 'Clear throughout the day.',
#                      'sunriseTime': 1652956500,
#                      'sunsetTime': 1653007020,
#                      'temperatureHigh': 91.86,
#                      'temperatureHighTime': 1652991300,
#                      'temperatureLow': 71.18,
#                      'temperatureLowTime': 1653044040,
#                      'temperatureMax': 91.86,
#                      'temperatureMaxTime': 1652991300,
#                      'temperatureMin': 70.76,
#                      'temperatureMinTime': 1652956920,
#                      'time': 1652932800,
#                      'uvIndex': 9,
#                      'uvIndexTime': 1652980080,
#                      'visibility': 10,
#                      'windBearing': 239,
#                      'windGust': 21.48,
#                      'windGustTime': 1652954400,
#                      'windSpeed': 7.5},
#                     {'apparentTemperatureHigh': 91.05,
#                      'apparentTemperatureHighTime': 1653077280,
#                      'apparentTemperatureLow': 74.92,
#                      'apparentTemperatureLowTime': 1653130440,
#                      'apparentTemperatureMax': 91.05,
#                      'apparentTemperatureMaxTime': 1653077280,
#                      'apparentTemperatureMin': 72.84,
#                      'apparentTemperatureMinTime': 1653043860,
#                      'cloudCover': 0.14,
#                      'dewPoint': 64.96,
#                      'humidity': 0.61,
#                      'icon': 'clear-day',
#                      'moonPhase': 0.69,
#                      'ozone': 315.8,
#                      'precipIntensity': 0.0001,
#                      'precipIntensityMax': 0.0008,
#                      'precipIntensityMaxTime': 1653080400,
#                      'precipProbability': 0.03,
#                      'precipType': 'rain',
#                      'pressure': 1013.7,
#                      'summary': 'Clear throughout the day.',
#                      'sunriseTime': 1653042900,
#                      'sunsetTime': 1653093420,
#                      'temperatureHigh': 91.55,
#                      'temperatureHighTime': 1653077280,
#                      'temperatureLow': 72.99,
#                      'temperatureLowTime': 1653130620,
#                      'temperatureMax': 91.55,
#                      'temperatureMaxTime': 1653077280,
#                      'temperatureMin': 71.18,
#                      'temperatureMinTime': 1653044040,
#                      'time': 1653019200,
#                      'uvIndex': 10,
#                      'uvIndexTime': 1653067260,
#                      'visibility': 10,
#                      'windBearing': 209,
#                      'windGust': 23.18,
#                      'windGustTime': 1653026160,
#                      'windSpeed': 6.78},
#                     {'apparentTemperatureHigh': 89.67,
#                      'apparentTemperatureHighTime': 1653161220,
#                      'apparentTemperatureLow': 76.58,
#                      'apparentTemperatureLowTime': 1653203640,
#                      'apparentTemperatureMax': 89.67,
#                      'apparentTemperatureMaxTime': 1653161220,
#                      'apparentTemperatureMin': 74.92,
#                      'apparentTemperatureMinTime': 1653130440,
#                      'cloudCover': 0.77,
#                      'dewPoint': 67.96,
#                      'humidity': 0.67,
#                      'icon': 'partly-cloudy-day',
#                      'moonPhase': 0.72,
#                      'ozone': 314.4,
#                      'precipIntensity': 0.0024,
#                      'precipIntensityMax': 0.0093,
#                      'precipIntensityMaxTime': 1653156480,
#                      'precipProbability': 0.25,
#                      'precipType': 'rain',
#                      'pressure': 1016.7,
#                      'summary': 'Humid and mostly cloudy throughout the day.',
#                      'sunriseTime': 1653129240,
#                      'sunsetTime': 1653179880,
#                      'temperatureHigh': 89.48,
#                      'temperatureHighTime': 1653161940,
#                      'temperatureLow': 74.69,
#                      'temperatureLowTime': 1653204300,
#                      'temperatureMax': 89.48,
#                      'temperatureMaxTime': 1653161940,
#                      'temperatureMin': 72.99,
#                      'temperatureMinTime': 1653130620,
#                      'time': 1653105600,
#                      'uvIndex': 7,
#                      'uvIndexTime': 1653150780,
#                      'visibility': 10,
#                      'windBearing': 210,
#                      'windGust': 23.91,
#                      'windGustTime': 1653178380,
#                      'windSpeed': 6.78},
#                     {'apparentTemperatureHigh': 85.75,
#                      'apparentTemperatureHighTime': 1653244800,
#                      'apparentTemperatureLow': 64.82,
#                      'apparentTemperatureLowTime': 1653303600,
#                      'apparentTemperatureMax': 85.75,
#                      'apparentTemperatureMaxTime': 1653244800,
#                      'apparentTemperatureMin': 72.41,
#                      'apparentTemperatureMinTime': 1653276480,
#                      'cloudCover': 0.97,
#                      'dewPoint': 69.9,
#                      'humidity': 0.81,
#                      'icon': 'rain',
#                      'moonPhase': 0.76,
#                      'ozone': 305.3,
#                      'precipIntensity': 0.007,
#                      'precipIntensityMax': 0.0211,
#                      'precipIntensityMaxTime': 1653257880,
#                      'precipProbability': 0.83,
#                      'precipType': 'rain',
#                      'pressure': 1019,
#                      'summary': 'Possible light rain in the afternoon and '
#                                 'evening.',
#                      'sunriseTime': 1653215640,
#                      'sunsetTime': 1653266340,
#                      'temperatureHigh': 82.05,
#                      'temperatureHighTime': 1653244920,
#                      'temperatureLow': 63.48,
#                      'temperatureLowTime': 1653303600,
#                      'temperatureMax': 82.05,
#                      'temperatureMaxTime': 1653244920,
#                      'temperatureMin': 71.29,
#                      'temperatureMinTime': 1653276720,
#                      'time': 1653192000,
#                      'uvIndex': 5,
#                      'uvIndexTime': 1653242220,
#                      'visibility': 9.389,
#                      'windBearing': 310,
#                      'windGust': 25.23,
#                      'windGustTime': 1653210360,
#                      'windSpeed': 7.06},
#                     {'apparentTemperatureHigh': 67.59,
#                      'apparentTemperatureHighTime': 1653346800,
#                      'apparentTemperatureLow': 60.18,
#                      'apparentTemperatureLowTime': 1653386880,
#                      'apparentTemperatureMax': 73,
#                      'apparentTemperatureMaxTime': 1653284280,
#                      'apparentTemperatureMin': 62.02,
#                      'apparentTemperatureMinTime': 1653323220,
#                      'cloudCover': 0.99,
#                      'dewPoint': 63.81,
#                      'humidity': 0.94,
#                      'icon': 'rain',
#                      'moonPhase': 0.79,
#                      'ozone': 309.9,
#                      'precipIntensity': 0.0113,
#                      'precipIntensityMax': 0.0953,
#                      'precipIntensityMaxTime': 1653296160,
#                      'precipProbability': 0.45,
#                      'precipType': 'rain',
#                      'pressure': 1022,
#                      'summary': 'Rain in the morning.',
#                      'sunriseTime': 1653301980,
#                      'sunsetTime': 1653352740,
#                      'temperatureHigh': 67.58,
#                      'temperatureHighTime': 1653346800,
#                      'temperatureLow': 59.48,
#                      'temperatureLowTime': 1653387240,
#                      'temperatureMax': 72.71,
#                      'temperatureMaxTime': 1653283740,
#                      'temperatureMin': 60.74,
#                      'temperatureMinTime': 1653324120,
#                      'time': 1653278400,
#                      'uvIndex': 5,
#                      'uvIndexTime': 1653327660,
#                      'visibility': 10,
#                      'windBearing': 89,
#                      'windGust': 28.32,
#                      'windGustTime': 1653362100,
#                      'windSpeed': 7.93},
#                     {'apparentTemperatureHigh': 70.76,
#                      'apparentTemperatureHighTime': 1653433200,
#                      'apparentTemperatureLow': 67.08,
#                      'apparentTemperatureLowTime': 1653472800,
#                      'apparentTemperatureMax': 70.89,
#                      'apparentTemperatureMaxTime': 1653436140,
#                      'apparentTemperatureMin': 60.18,
#                      'apparentTemperatureMinTime': 1653386880,
#                      'cloudCover': 0.99,
#                      'dewPoint': 63.08,
#                      'humidity': 0.92,
#                      'icon': 'cloudy',
#                      'moonPhase': 0.83,
#                      'ozone': 301.5,
#                      'precipIntensity': 0,
#                      'precipIntensityMax': 0.0004,
#                      'precipIntensityMaxTime': 1653451200,
#                      'precipProbability': 0.02,
#                      'pressure': 1019.6,
#                      'summary': 'Overcast throughout the day.',
#                      'sunriseTime': 1653388380,
#                      'sunsetTime': 1653439200,
#                      'temperatureHigh': 70.68,
#                      'temperatureHighTime': 1653433200,
#                      'temperatureLow': 64.78,
#                      'temperatureLowTime': 1653476400,
#                      'temperatureMax': 70.81,
#                      'temperatureMaxTime': 1653436140,
#                      'temperatureMin': 59.48,
#                      'temperatureMinTime': 1653387240,
#                      'time': 1653364800,
#                      'uvIndex': 5,
#                      'uvIndexTime': 1653414060,
#                      'visibility': 10,
#                      'windBearing': 118,
#                      'windGust': 28.19,
#                      'windGustTime': 1653364800,
#                      'windSpeed': 6.48}],
#            'icon': 'rain',
#            'summary': 'Rain on Sunday and Monday.'},
#  'flags': {'nearest-station': 2.16,
#            'sources': ['nwspa',
#                        'cmc',
#                        'gfs',
#                        'hrrr',
#                        'icon',
#                        'isd',
#                        'madis',
#                        'nam',
#                        'sref',
#                        'darksky',
#                        'nearest-precip'],
#            'units': 'us'},
#  'hourly': {'data': [{'apparentTemperature': 74.9,
#                       'cloudCover': 0.06,
#                       'dewPoint': 52.84,
#                       'humidity': 0.46,
#                       'icon': 'clear-day',
#                       'ozone': 325.1,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1018.2,
#                       'summary': 'Clear',
#                       'temperature': 74.9,
#                       'time': 1652799600,
#                       'uvIndex': 6,
#                       'visibility': 10,
#                       'windBearing': 66,
#                       'windGust': 6.72,
#                       'windSpeed': 3.82},
#                      {'apparentTemperature': 77.54,
#                       'cloudCover': 0.07,
#                       'dewPoint': 51.5,
#                       'humidity': 0.4,
#                       'icon': 'clear-day',
#                       'ozone': 325.9,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1018,
#                       'summary': 'Clear',
#                       'temperature': 77.54,
#                       'time': 1652803200,
#                       'uvIndex': 8,
#                       'visibility': 10,
#                       'windBearing': 46,
#                       'windGust': 5.67,
#                       'windSpeed': 3.21},
#                      {'apparentTemperature': 79.68,
#                       'cloudCover': 0.07,
#                       'dewPoint': 50.46,
#                       'humidity': 0.36,
#                       'icon': 'clear-day',
#                       'ozone': 327.6,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1017.5,
#                       'summary': 'Clear',
#                       'temperature': 79.68,
#                       'time': 1652806800,
#                       'uvIndex': 9,
#                       'visibility': 10,
#                       'windBearing': 10,
#                       'windGust': 4.92,
#                       'windSpeed': 2.63},
#                      {'apparentTemperature': 81.1,
#                       'cloudCover': 0.06,
#                       'dewPoint': 49.61,
#                       'humidity': 0.33,
#                       'icon': 'clear-day',
#                       'ozone': 328.8,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1016.7,
#                       'summary': 'Clear',
#                       'temperature': 81.1,
#                       'time': 1652810400,
#                       'uvIndex': 9,
#                       'visibility': 10,
#                       'windBearing': 342,
#                       'windGust': 6.3,
#                       'windSpeed': 3.37},
#                      {'apparentTemperature': 82.33,
#                       'cloudCover': 0.07,
#                       'dewPoint': 48.55,
#                       'humidity': 0.31,
#                       'icon': 'clear-day',
#                       'ozone': 328.8,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1016.3,
#                       'summary': 'Clear',
#                       'temperature': 82.33,
#                       'time': 1652814000,
#                       'uvIndex': 8,
#                       'visibility': 10,
#                       'windBearing': 335,
#                       'windGust': 7.65,
#                       'windSpeed': 4.75},
#                      {'apparentTemperature': 83.41,
#                       'cloudCover': 0.07,
#                       'dewPoint': 47.42,
#                       'humidity': 0.29,
#                       'icon': 'clear-day',
#                       'ozone': 328.5,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1015.7,
#                       'summary': 'Clear',
#                       'temperature': 83.41,
#                       'time': 1652817600,
#                       'uvIndex': 6,
#                       'visibility': 10,
#                       'windBearing': 339,
#                       'windGust': 7.17,
#                       'windSpeed': 5.22},
#                      {'apparentTemperature': 83.57,
#                       'cloudCover': 0.06,
#                       'dewPoint': 47,
#                       'humidity': 0.28,
#                       'icon': 'clear-day',
#                       'ozone': 327.3,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1015.4,
#                       'summary': 'Clear',
#                       'temperature': 83.57,
#                       'time': 1652821200,
#                       'uvIndex': 4,
#                       'visibility': 10,
#                       'windBearing': 337,
#                       'windGust': 7.49,
#                       'windSpeed': 6.01},
#                      {'apparentTemperature': 82.99,
#                       'cloudCover': 0,
#                       'dewPoint': 46.04,
#                       'humidity': 0.27,
#                       'icon': 'clear-day',
#                       'ozone': 325.7,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1015.1,
#                       'summary': 'Clear',
#                       'temperature': 82.99,
#                       'time': 1652824800,
#                       'uvIndex': 2,
#                       'visibility': 10,
#                       'windBearing': 338,
#                       'windGust': 6.82,
#                       'windSpeed': 5.77},
#                      {'apparentTemperature': 81.49,
#                       'cloudCover': 0.06,
#                       'dewPoint': 47.43,
#                       'humidity': 0.3,
#                       'icon': 'clear-day',
#                       'ozone': 324.6,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1015.3,
#                       'summary': 'Clear',
#                       'temperature': 81.49,
#                       'time': 1652828400,
#                       'uvIndex': 1,
#                       'visibility': 10,
#                       'windBearing': 334,
#                       'windGust': 7.2,
#                       'windSpeed': 5.67},
#                      {'apparentTemperature': 79.05,
#                       'cloudCover': 0.01,
#                       'dewPoint': 49.01,
#                       'humidity': 0.35,
#                       'icon': 'clear-day',
#                       'ozone': 323.6,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1015.6,
#                       'summary': 'Clear',
#                       'temperature': 79.05,
#                       'time': 1652832000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 329,
#                       'windGust': 9.1,
#                       'windSpeed': 5.11},
#                      {'apparentTemperature': 75.65,
#                       'cloudCover': 0.01,
#                       'dewPoint': 50.41,
#                       'humidity': 0.41,
#                       'icon': 'clear-night',
#                       'ozone': 322.4,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1016.1,
#                       'summary': 'Clear',
#                       'temperature': 75.65,
#                       'time': 1652835600,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 331,
#                       'windGust': 8.75,
#                       'windSpeed': 4.46},
#                      {'apparentTemperature': 73.27,
#                       'cloudCover': 0.02,
#                       'dewPoint': 51.75,
#                       'humidity': 0.47,
#                       'icon': 'clear-night',
#                       'ozone': 320.6,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1016.6,
#                       'summary': 'Clear',
#                       'temperature': 73.27,
#                       'time': 1652839200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 344,
#                       'windGust': 8.85,
#                       'windSpeed': 4},
#                      {'apparentTemperature': 71.53,
#                       'cloudCover': 0.03,
#                       'dewPoint': 51.63,
#                       'humidity': 0.49,
#                       'icon': 'clear-night',
#                       'ozone': 319.6,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1016.9,
#                       'summary': 'Clear',
#                       'temperature': 71.53,
#                       'time': 1652842800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 5,
#                       'windGust': 8.01,
#                       'windSpeed': 3.71},
#                      {'apparentTemperature': 70.09,
#                       'cloudCover': 0.17,
#                       'dewPoint': 51.81,
#                       'humidity': 0.52,
#                       'icon': 'clear-night',
#                       'ozone': 318.4,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1016.6,
#                       'summary': 'Clear',
#                       'temperature': 70.09,
#                       'time': 1652846400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 19,
#                       'windGust': 6.51,
#                       'windSpeed': 3.1},
#                      {'apparentTemperature': 68.41,
#                       'cloudCover': 0.1,
#                       'dewPoint': 53.39,
#                       'humidity': 0.59,
#                       'icon': 'clear-night',
#                       'ozone': 316.2,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1016.4,
#                       'summary': 'Clear',
#                       'temperature': 68.41,
#                       'time': 1652850000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 4,
#                       'windGust': 3.31,
#                       'windSpeed': 2.19},
#                      {'apparentTemperature': 66.3,
#                       'cloudCover': 0.12,
#                       'dewPoint': 53.4,
#                       'humidity': 0.63,
#                       'icon': 'clear-night',
#                       'ozone': 314.6,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1016,
#                       'summary': 'Clear',
#                       'temperature': 66.3,
#                       'time': 1652853600,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 13,
#                       'windGust': 2.57,
#                       'windSpeed': 2.01},
#                      {'apparentTemperature': 64.46,
#                       'cloudCover': 0.12,
#                       'dewPoint': 53.28,
#                       'humidity': 0.67,
#                       'icon': 'clear-night',
#                       'ozone': 315.4,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1015.8,
#                       'summary': 'Clear',
#                       'temperature': 64.46,
#                       'time': 1652857200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 31,
#                       'windGust': 2.82,
#                       'windSpeed': 2.07},
#                      {'apparentTemperature': 62.98,
#                       'cloudCover': 0.11,
#                       'dewPoint': 53.1,
#                       'humidity': 0.7,
#                       'icon': 'clear-night',
#                       'ozone': 315.3,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1016.1,
#                       'summary': 'Clear',
#                       'temperature': 62.98,
#                       'time': 1652860800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 48,
#                       'windGust': 4.54,
#                       'windSpeed': 2.44},
#                      {'apparentTemperature': 63.64,
#                       'cloudCover': 0.17,
#                       'dewPoint': 53.24,
#                       'humidity': 0.69,
#                       'icon': 'clear-night',
#                       'ozone': 314.2,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1016.5,
#                       'summary': 'Clear',
#                       'temperature': 63.64,
#                       'time': 1652864400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 57,
#                       'windGust': 5.74,
#                       'windSpeed': 2.59},
#                      {'apparentTemperature': 62.08,
#                       'cloudCover': 0.14,
#                       'dewPoint': 53.28,
#                       'humidity': 0.73,
#                       'icon': 'clear-night',
#                       'ozone': 314.2,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1017,
#                       'summary': 'Clear',
#                       'temperature': 62.08,
#                       'time': 1652868000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 64,
#                       'windGust': 4.22,
#                       'windSpeed': 2.65},
#                      {'apparentTemperature': 64.06,
#                       'cloudCover': 0.21,
#                       'dewPoint': 53.77,
#                       'humidity': 0.69,
#                       'icon': 'clear-day',
#                       'ozone': 316,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1017.6,
#                       'summary': 'Clear',
#                       'temperature': 64.06,
#                       'time': 1652871600,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 70,
#                       'windGust': 4.78,
#                       'windSpeed': 2.91},
#                      {'apparentTemperature': 64.87,
#                       'cloudCover': 0.2,
#                       'dewPoint': 54.57,
#                       'humidity': 0.69,
#                       'icon': 'clear-day',
#                       'ozone': 318.9,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1018.1,
#                       'summary': 'Clear',
#                       'temperature': 64.87,
#                       'time': 1652875200,
#                       'uvIndex': 1,
#                       'visibility': 10,
#                       'windBearing': 85,
#                       'windGust': 7.31,
#                       'windSpeed': 3.61},
#                      {'apparentTemperature': 70.01,
#                       'cloudCover': 0.18,
#                       'dewPoint': 55.81,
#                       'humidity': 0.61,
#                       'icon': 'clear-day',
#                       'ozone': 320.4,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1018.3,
#                       'summary': 'Clear',
#                       'temperature': 70.01,
#                       'time': 1652878800,
#                       'uvIndex': 2,
#                       'visibility': 10,
#                       'windBearing': 103,
#                       'windGust': 7.41,
#                       'windSpeed': 4.15},
#                      {'apparentTemperature': 74.72,
#                       'cloudCover': 0.32,
#                       'dewPoint': 56.59,
#                       'humidity': 0.53,
#                       'icon': 'partly-cloudy-day',
#                       'ozone': 320,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1018.3,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 74.72,
#                       'time': 1652882400,
#                       'uvIndex': 4,
#                       'visibility': 10,
#                       'windBearing': 131,
#                       'windGust': 9.39,
#                       'windSpeed': 5.23},
#                      {'apparentTemperature': 78.56,
#                       'cloudCover': 0.16,
#                       'dewPoint': 56.68,
#                       'humidity': 0.47,
#                       'icon': 'clear-day',
#                       'ozone': 319.6,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1018.1,
#                       'summary': 'Clear',
#                       'temperature': 78.56,
#                       'time': 1652886000,
#                       'uvIndex': 6,
#                       'visibility': 10,
#                       'windBearing': 154,
#                       'windGust': 11.06,
#                       'windSpeed': 6.39},
#                      {'apparentTemperature': 81.36,
#                       'cloudCover': 0.12,
#                       'dewPoint': 55.63,
#                       'humidity': 0.41,
#                       'icon': 'clear-day',
#                       'ozone': 321.1,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1017.7,
#                       'summary': 'Clear',
#                       'temperature': 81.36,
#                       'time': 1652889600,
#                       'uvIndex': 8,
#                       'visibility': 10,
#                       'windBearing': 177,
#                       'windGust': 10.51,
#                       'windSpeed': 6.71},
#                      {'apparentTemperature': 83.31,
#                       'cloudCover': 0.06,
#                       'dewPoint': 54.46,
#                       'humidity': 0.37,
#                       'icon': 'clear-day',
#                       'ozone': 321,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1017.2,
#                       'summary': 'Clear',
#                       'temperature': 83.31,
#                       'time': 1652893200,
#                       'uvIndex': 10,
#                       'visibility': 10,
#                       'windBearing': 199,
#                       'windGust': 9.68,
#                       'windSpeed': 6.77},
#                      {'apparentTemperature': 85.06,
#                       'cloudCover': 0.04,
#                       'dewPoint': 54.07,
#                       'humidity': 0.35,
#                       'icon': 'clear-day',
#                       'ozone': 322.6,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1016.5,
#                       'summary': 'Clear',
#                       'temperature': 85.06,
#                       'time': 1652896800,
#                       'uvIndex': 10,
#                       'visibility': 10,
#                       'windBearing': 209,
#                       'windGust': 9.1,
#                       'windSpeed': 6.92},
#                      {'apparentTemperature': 86.88,
#                       'cloudCover': 0.05,
#                       'dewPoint': 53.92,
#                       'humidity': 0.33,
#                       'icon': 'clear-day',
#                       'ozone': 322.8,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1015.6,
#                       'summary': 'Clear',
#                       'temperature': 86.88,
#                       'time': 1652900400,
#                       'uvIndex': 9,
#                       'visibility': 10,
#                       'windBearing': 223,
#                       'windGust': 8.93,
#                       'windSpeed': 7.06},
#                      {'apparentTemperature': 88.01,
#                       'cloudCover': 0.12,
#                       'dewPoint': 53.41,
#                       'humidity': 0.31,
#                       'icon': 'clear-day',
#                       'ozone': 322.5,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1014.6,
#                       'summary': 'Clear',
#                       'temperature': 88.01,
#                       'time': 1652904000,
#                       'uvIndex': 6,
#                       'visibility': 10,
#                       'windBearing': 223,
#                       'windGust': 8.09,
#                       'windSpeed': 7.07},
#                      {'apparentTemperature': 88.42,
#                       'cloudCover': 0.18,
#                       'dewPoint': 53.24,
#                       'humidity': 0.3,
#                       'icon': 'clear-day',
#                       'ozone': 322.8,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013.8,
#                       'summary': 'Clear',
#                       'temperature': 88.42,
#                       'time': 1652907600,
#                       'uvIndex': 4,
#                       'visibility': 10,
#                       'windBearing': 226,
#                       'windGust': 8.66,
#                       'windSpeed': 7.38},
#                      {'apparentTemperature': 87.8,
#                       'cloudCover': 0.19,
#                       'dewPoint': 53.75,
#                       'humidity': 0.31,
#                       'icon': 'clear-day',
#                       'ozone': 321.8,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013.4,
#                       'summary': 'Clear',
#                       'temperature': 87.8,
#                       'time': 1652911200,
#                       'uvIndex': 2,
#                       'visibility': 10,
#                       'windBearing': 220,
#                       'windGust': 10.14,
#                       'windSpeed': 7.66},
#                      {'apparentTemperature': 86.36,
#                       'cloudCover': 0.12,
#                       'dewPoint': 55.06,
#                       'humidity': 0.34,
#                       'icon': 'clear-day',
#                       'ozone': 320.6,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013,
#                       'summary': 'Clear',
#                       'temperature': 86.36,
#                       'time': 1652914800,
#                       'uvIndex': 1,
#                       'visibility': 10,
#                       'windBearing': 220,
#                       'windGust': 12.55,
#                       'windSpeed': 7.86},
#                      {'apparentTemperature': 83.71,
#                       'cloudCover': 0.13,
#                       'dewPoint': 56.82,
#                       'humidity': 0.4,
#                       'icon': 'clear-day',
#                       'ozone': 319.2,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013,
#                       'summary': 'Clear',
#                       'temperature': 83.71,
#                       'time': 1652918400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 222,
#                       'windGust': 13.3,
#                       'windSpeed': 6.88},
#                      {'apparentTemperature': 80.94,
#                       'cloudCover': 0.19,
#                       'dewPoint': 58.62,
#                       'humidity': 0.47,
#                       'icon': 'clear-night',
#                       'ozone': 318.7,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013.2,
#                       'summary': 'Clear',
#                       'temperature': 80.44,
#                       'time': 1652922000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 218,
#                       'windGust': 11.52,
#                       'windSpeed': 5.97},
#                      {'apparentTemperature': 78.33,
#                       'cloudCover': 0.27,
#                       'dewPoint': 60.13,
#                       'humidity': 0.54,
#                       'icon': 'clear-night',
#                       'ozone': 318.5,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013.5,
#                       'summary': 'Clear',
#                       'temperature': 78.28,
#                       'time': 1652925600,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 217,
#                       'windGust': 13.63,
#                       'windSpeed': 5.36},
#                      {'apparentTemperature': 77.03,
#                       'cloudCover': 0.09,
#                       'dewPoint': 61.11,
#                       'humidity': 0.58,
#                       'icon': 'clear-night',
#                       'ozone': 318,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013.6,
#                       'summary': 'Clear',
#                       'temperature': 76.9,
#                       'time': 1652929200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 217,
#                       'windGust': 13.4,
#                       'windSpeed': 4.95},
#                      {'apparentTemperature': 76.38,
#                       'cloudCover': 0.16,
#                       'dewPoint': 61.6,
#                       'humidity': 0.61,
#                       'icon': 'clear-night',
#                       'ozone': 317.1,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013.7,
#                       'summary': 'Clear',
#                       'temperature': 76.21,
#                       'time': 1652932800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 215,
#                       'windGust': 14.4,
#                       'windSpeed': 4.76},
#                      {'apparentTemperature': 75.92,
#                       'cloudCover': 0.27,
#                       'dewPoint': 62.04,
#                       'humidity': 0.63,
#                       'icon': 'clear-night',
#                       'ozone': 317.2,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013.6,
#                       'summary': 'Clear',
#                       'temperature': 75.7,
#                       'time': 1652936400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 215,
#                       'windGust': 15.61,
#                       'windSpeed': 4.8},
#                      {'apparentTemperature': 75.48,
#                       'cloudCover': 0.33,
#                       'dewPoint': 62.59,
#                       'humidity': 0.65,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 317.3,
#                       'precipIntensity': 0,
#                       'precipProbability': 0,
#                       'pressure': 1013.1,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 75.21,
#                       'time': 1652940000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 215,
#                       'windGust': 18.77,
#                       'windSpeed': 5.17},
#                      {'apparentTemperature': 74.9,
#                       'cloudCover': 0.46,
#                       'dewPoint': 63.38,
#                       'humidity': 0.68,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 316.9,
#                       'precipIntensity': 0.0012,
#                       'precipProbability': 0.01,
#                       'precipType': 'rain',
#                       'pressure': 1012.6,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 74.54,
#                       'time': 1652943600,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 219,
#                       'windGust': 20.47,
#                       'windSpeed': 5.35},
#                      {'apparentTemperature': 73.27,
#                       'cloudCover': 0.48,
#                       'dewPoint': 65.09,
#                       'humidity': 0.77,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 315.6,
#                       'precipIntensity': 0.0053,
#                       'precipProbability': 0.02,
#                       'precipType': 'rain',
#                       'pressure': 1012.5,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 72.68,
#                       'time': 1652947200,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 232,
#                       'windGust': 19.42,
#                       'windSpeed': 5.48},
#                      {'apparentTemperature': 72.6,
#                       'cloudCover': 0.51,
#                       'dewPoint': 65.88,
#                       'humidity': 0.81,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 314.5,
#                       'precipIntensity': 0.0026,
#                       'precipProbability': 0.02,
#                       'precipType': 'rain',
#                       'pressure': 1012.6,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 71.88,
#                       'time': 1652950800,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 235,
#                       'windGust': 19.83,
#                       'windSpeed': 5.51},
#                      {'apparentTemperature': 72.3,
#                       'cloudCover': 0.5,
#                       'dewPoint': 66.67,
#                       'humidity': 0.85,
#                       'icon': 'partly-cloudy-night',
#                       'ozone': 313.8,
#                       'precipIntensity': 0.0014,
#                       'precipProbability': 0.01,
#                       'precipType': 'rain',
#                       'pressure': 1013,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 71.46,
#                       'time': 1652954400,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 240,
#                       'windGust': 21.48,
#                       'windSpeed': 5.79},
#                      {'apparentTemperature': 72.34,
#                       'cloudCover': 0.54,
#                       'dewPoint': 67.73,
#                       'humidity': 0.88,
#                       'icon': 'partly-cloudy-day',
#                       'ozone': 313.8,
#                       'precipIntensity': 0.0017,
#                       'precipProbability': 0.01,
#                       'precipType': 'rain',
#                       'pressure': 1013.5,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 71.35,
#                       'time': 1652958000,
#                       'uvIndex': 0,
#                       'visibility': 10,
#                       'windBearing': 242,
#                       'windGust': 19.71,
#                       'windSpeed': 5.8},
#                      {'apparentTemperature': 73.96,
#                       'cloudCover': 0.34,
#                       'dewPoint': 68.75,
#                       'humidity': 0.87,
#                       'icon': 'partly-cloudy-day',
#                       'ozone': 315.8,
#                       'precipIntensity': 0.0011,
#                       'precipProbability': 0.01,
#                       'precipType': 'rain',
#                       'pressure': 1013.9,
#                       'summary': 'Partly Cloudy',
#                       'temperature': 72.88,
#                       'time': 1652961600,
#                       'uvIndex': 1,
#                       'visibility': 10,
#                       'windBearing': 246,
#                       'windGust': 18.95,
#                       'windSpeed': 6.47},
#                      {'apparentTemperature': 77.26,
#                       'cloudCover': 0.21,
#                       'dewPoint': 69.78,
#                       'humidity': 0.81,
#                       'icon': 'clear-day',
#                       'ozone': 315.9,
#                       'precipIntensity': 0.0002,
#                       'precipProbability': 0.01,
#                       'precipType': 'rain',
#                       'pressure': 1014.3,
#                       'summary': 'Clear',
#                       'temperature': 76.15,
#                       'time': 1652965200,
#                       'uvIndex': 2,
#                       'visibility': 10,
#                       'windBearing': 248,
#                       'windGust': 17.51,
#                       'windSpeed': 7.39},
#                      {'apparentTemperature': 83.11,
#                       'cloudCover': 0.17,
#                       'dewPoint': 70.24,
#                       'humidity': 0.72,
#                       'icon': 'clear-day',
#                       'ozone': 316.2,
#                       'precipIntensity': 0.0012,
#                       'precipProbability': 0.01,
#                       'precipType': 'rain',
#                       'pressure': 1013.8,
#                       'summary': 'Clear',
#                       'temperature': 79.92,
#                       'time': 1652968800,
#                       'uvIndex': 4,
#                       'visibility': 10,
#                       'windBearing': 264,
#                       'windGust': 17.2,
#                       'windSpeed': 8.29},
#                      {'apparentTemperature': 87.04,
#                       'cloudCover': 0.21,
#                       'dewPoint': 70.49,
#                       'humidity': 0.67,
#                       'icon': 'clear-day',
#                       'ozone': 316.6,
#                       'precipIntensity': 0.002,
#                       'precipProbability': 0.01,
#                       'precipType': 'rain',
#                       'pressure': 1013.6,
#                       'summary': 'Clear',
#                       'temperature': 82.76,
#                       'time': 1652972400,
#                       'uvIndex': 6,
#                       'visibility': 10,
#                       'windBearing': 259,
#                       'windGust': 16.21,
#                       'windSpeed': 8.94}],
#             'icon': 'clear-day',
#             'summary': 'Clear throughout the day.'},
#  'latitude': 33.884,
#  'longitude': -84.5144,
#  'minutely': {'data': [{'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802900},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652802960},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803020},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803080},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803140},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803200},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803260},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803320},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803380},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803440},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803500},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803560},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803620},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803680},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803740},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803800},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803860},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803920},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652803980},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804040},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804100},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804160},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804220},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804280},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804340},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804400},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804460},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804520},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804580},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804640},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804700},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804760},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804820},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804880},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652804940},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652805000},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652805060},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652805120},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652805180},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652805240},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652805300},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652805360},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652805420},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652805480},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652805540},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652805600},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652805660},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652805720},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652805780},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652805840},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652805900},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652805960},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652806020},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652806080},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652806140},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652806200},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652806260},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652806320},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652806380},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652806440},
#                        {'precipIntensity': 0,
#                         'precipProbability': 0,
#                         'time': 1652806500}],
#               'icon': 'clear-day',
#               'summary': 'Clear for the hour.'},
#  'offset': -4,
#  'timezone': 'America/New_York'}

# %% [markdown]
# ## Advanced API tools:  Requests
# * Requests - HTTP for Humans:  http://docs.python-requests.org/en/master/
# * Nice methods for each HTTP verb
# * Easy response handling for most common data formats
# * Can handle cookies, authentication, streaming downloads
# * Lots of community support for advanced usage:  OAuth, Caching, Async

# %%
import requests

# %%
# !pip3 install requests
# OR python3 -m pip install requests

# %%
import requests
response = requests.get('https://xkcd.com')
print(response.text)
print(response.headers)
print(response.status_code)

# %%
help(requests.get)

# %% [markdown]
# ## Common API Response formats

# %% [markdown]
# ## CSV (Comma-Separated Values) / Delimited text
# * One of the simplest forms of data transfer formats
# * Often simply a direct dump from a database or spreadsheet
# * Very efficient data transfer (little metadata)
# * Popular in government data sources and data science
# * Has a few problems that make it less popular on the client side
#     * No data type support - everything is a string
#     * Delimeters in text need to be handled specially (usually quoting)
#     * There are several subtley different "dialects" from various tools (no real specification)
#     * Not terribly human-readable either

# %%
import requests
import csv

# Hourly earthquake data for earthquakes over 1.0 magnitude, per USGS
response = requests.get('https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_hour.csv')
print(response.text)
# Sometimes we have to deal with different data encodings (ASCII, UTF-8, etc.)
reader = csv.DictReader(response.iter_lines(decode_unicode=True))
for row in reader:
    print(row['time'], row['place'], row['mag'])

# %% [markdown]
# ## XML (eXtensible Markup Language)
# * Became popular as the Web took off (late 1990s)
# * Intended to be very easy for humans to read (compared to binary formats)
# * Text only - once again to avoid prior binary protocols
# * No data types - everything is a string
# * Very verbose format - not great efficiency for very large files
# * Not really streamable (there are workarounds)
# * Official spec (but there are many extensions):
# * Still very popular as a configuration format (C#, Java, etc)

# %%
import requests
from xml.etree import ElementTree as ET

response = requests.get('https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_week_age_link.kml')

print(response.text)
print()
root = ET.fromstring(response.text)
print(root.tag)
document = root.find('{http://www.opengis.net/kml/2.2}Document')
for child in document:
    print(child.tag)
    print(child.text)

# %% [markdown]
# ## JSON (JavaScript Object Notation)
# * Syntax is valid, literal JavaScript objects
# * Gained rapid popularity because it is simple concise, and easy to deal with in JavaScript
# * Translates easily to Python objects
# * Still pretty human readable
# * Supports a limited set of data types (number, string, boolean, "object", and array)
# * Has an official specification:  https://www.json.org/json-en.html

# %%
import requests
from pprint import pprint

response = requests.get('https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_hour.geojson')

data = response.json()
pprint(data)
print()
for record in data['features']:
    print(record['properties']['time'], record['properties']['place'], record['properties']['mag'])
# Out:
# {'bbox': [-155.4553, 35.9671667, 0.3, -117.4121667, 62.9306, 61.5],
#  'features': [{'geometry': {'coordinates': [-155.4553, 57.1673, 0.3],
#                             'type': 'Point'},
#                'id': 'ak0226avmj83',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '0226avmj83',
#                               'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0226avmj83.geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',ak0226avmj83,',
#                               'mag': 1.9,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ak',
#                               'nst': None,
#                               'place': '74 km SW of Karluk, Alaska',
#                               'rms': 0.66,
#                               'sig': 56,
#                               'sources': ',ak,',
#                               'status': 'automatic',
#                               'time': 1652813272198,
#                               'title': 'M 1.9 - 74 km SW of Karluk, Alaska',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',origin,phase-data,',
#                               'tz': None,
#                               'updated': 1652813386249,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0226avmj83'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-149.637, 62.9306, 61.5],
#                             'type': 'Point'},
#                'id': 'ak0226avhppt',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '0226avhppt',
#                               'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0226avhppt.geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',ak0226avhppt,',
#                               'mag': 1.2,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ak',
#                               'nst': None,
#                               'place': '58 km NNE of Chase, Alaska',
#                               'rms': 1.01,
#                               'sig': 22,
#                               'sources': ',ak,',
#                               'status': 'automatic',
#                               'time': 1652811903535,
#                               'title': 'M 1.2 - 58 km NNE of Chase, Alaska',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',origin,phase-data,',
#                               'tz': None,
#                               'updated': 1652812054677,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0226avhppt'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-117.4121667, 35.9671667, 1.66],
#                             'type': 'Point'},
#                'id': 'ci40021311',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '40021311',
#                               'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40021311.geojson',
#                               'dmin': 0.1293,
#                               'felt': None,
#                               'gap': 94,
#                               'ids': ',ci40021311,',
#                               'mag': 1.79,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ci',
#                               'nst': 25,
#                               'place': '22km N of Searles Valley, CA',
#                               'rms': 0.12,
#                               'sig': 49,
#                               'sources': ',ci,',
#                               'status': 'automatic',
#                               'time': 1652811771340,
#                               'title': 'M 1.8 - 22km N of Searles Valley, CA',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': None,
#                               'updated': 1652811988829,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40021311'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-155.1514, 57.5909, 57.2],
#                             'type': 'Point'},
#                'id': 'ak0226avft63',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '0226avft63',
#                               'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0226avft63.geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',ak0226avft63,',
#                               'mag': 1.5,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ak',
#                               'nst': None,
#                               'place': '41 km W of Karluk, Alaska',
#                               'rms': 0.46,
#                               'sig': 35,
#                               'sources': ',ak,',
#                               'status': 'automatic',
#                               'time': 1652811375158,
#                               'title': 'M 1.5 - 41 km W of Karluk, Alaska',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',origin,phase-data,',
#                               'tz': None,
#                               'updated': 1652811473599,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0226avft63'},
#                'type': 'Feature'}],
#  'metadata': {'api': '1.10.3',
#               'count': 4,
#               'generated': 1652813851000,
#               'status': 200,
#               'title': 'USGS Magnitude 1.0+ Earthquakes, Past Hour',
#               'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_hour.geojson'},
#  'type': 'FeatureCollection'}
#
# 1652813272198 74 km SW of Karluk, Alaska 1.9
# 1652811903535 58 km NNE of Chase, Alaska 1.2
# 1652811771340 22km N of Searles Valley, CA 1.79
# 1652811375158 41 km W of Karluk, Alaska 1.5

# %% [markdown]
# ## Lab: API Requests
#
# * Using the `requests` package, and the API key above, write a function that makes a request for your own location to the DarkSky API, and print out the response data.

# %%
import requests
# from pprint import pprint
import json
r = requests.get('https://api.darksky.net/forecast/1d8c58ed1d54f96f939e706c788650f1/43.071568,-70.762245') #, auth=('user', 'pass'))

data = r.json()
# pprint(data)
temp = data['currently']['temperature']
print(f'Current temperature is {temp}')
# Out:
# Current temperature is 70.25

# %%
cart = ['book1', 'book2', 'book3', 'book4', 'book5']
for i in cart:
    print(i)
# Out:
# book1
# book2
# book3
# book4
# book5

# %% [markdown]
# ## Other API concerns
# * Not all APIs are RESTful - you may need to deal with a proprietary protocol or simply request files
# * Authorization - many APIs require keys, tokens, or other credentials
# * Network outages
# * Rate limiting, tiering of access

# %% [markdown]
# ## But what if the site or web app doesn't offer an API?

# %% [markdown]
# # Web Scraping
#
# ### Requesting web pages built to render displays for HUMANS and extracting the information we want

# %% [markdown]
# ## Why should web scraping be a fallback?
# * More manual trial and error up front
# * Pages meant for humans may change frequently for any reason
# * Pages meant for display may have data scattered or buried
# * Popularity of Javascript frameworks may make data even harder to find

# %% [markdown]
# ## BeautifulSoup - Python package for parsing HTML
# * Offers support for various parsers (html, xml, lxml)
# * Provides easy methods and properties for navigating the markup "tree"
# * Search by HTML tags, attributes, CSS class, etc.
# * Regular expression support

# %%
import requests
import bs4

response = requests.get('https://cnn.com')
soup = bs4.BeautifulSoup(response.text)
soup

# %%
soup.title

# %%
soup.body.div

# %%
for child in soup.body.children:
    print(child)

# %%
soup.find_all('a')

# %% [markdown]
# ## That's a mess - but sometimes we can cheat a little...

# %%
response = requests.get('http://rss.cnn.com/rss/cnn_topstories.rss')
soup = bs4.BeautifulSoup(response.text)

soup.rss.find_all('title')

# %%
headlines = [node.string for node in soup.rss.find_all('title')]
headlines

# %% [markdown]
# ## Bonus Lab:  Web Scraping
#
# Using BeautifulSoup4, scrap the Wikipedia page for the History Python to obtain the following information:
# * What is the sum total length of support time for each major version of Python (i.e. 0.x, 1.x, 2.x, 3.x)
# * How much time was each major version supported after the next major version appeared?
# * Display the list of the final version for each major version

# %% [markdown]
# ## Python and Databases

# %% [markdown]
# ## DBAPI2:  The Python way to handle databases
#
# DBAPI2 is an API specification (https://www.python.org/dev/peps/pep-0249/) that defines a set of Python objects that are available when querying database engines.  While there are a very large number of database engines, and several database connectivity standards (ODBC, JDBC, etc), the DBAPI2 objects are what you see on the Python side.
#
# DBAPI2 **is**:
# * A common interface in Python that makes it simpler to switch databases
# * Provided by Python database driver packages
# * Simple and straightforward
#
# DBAPI2 **is not**:
# * A translation layer for SQL queries
# * An Object-Relational Mapper
# * A Python implementation of any database-specific features

# %% [markdown]
# ## `sqlite3` - The built-in database
# * Open-source database engine
# * Simple file-based storage
# * Great for prototyping
# * SQL compliant (almost)
# * Does NOT support parallel access (don't put it in production web apps!)

# %%
query = """
CREATE TABLE users (user_id INTEGER, username TEXT, email TEXT, pto_days REAL)
"""

# %%
import sqlite3

# "Connect" to the database
conn = sqlite3.connect('example.db')

# Get a cursor from the connection
cursor = conn.cursor()

# Execute a SQL query
cursor.execute(query)

# Inspect the results, if any
result = cursor.fetchone()
print(result)


# Commit the changes
conn.commit()
# Close the connection
conn.close()

# %%
# !ls -al *.db

# %%
insert_query = """
INSERT INTO users
VALUES
(1, "jrrickerson", "jrrickerson@redrivetstudios.com", 15.0),
(2, "dave", "dws@developintelligence.com", 20.0),
(3, "ace", "ace@developintelligence.com", 11.5);
"""

conn = sqlite3.connect('example.db')
cursor = conn.cursor()
cursor.execute(insert_query)
result = cursor.fetchone()
print(result)

conn.commit()
conn.close()

# %%
# Support for "with"

with sqlite3.connect('example.db') as conn:
    query = 'SELECT * FROM users'
    cursor = conn.cursor()
    cursor.execute(query)
    result = cursor.fetchall()
    print(result)

# %%
# Cursors support iteration

with sqlite3.connect('example.db') as conn:
    query = 'SELECT * FROM users'
    cursor = conn.cursor()
    for row in cursor.execute(query):
        print(row[1], row[3])

# %%
# Row objects allow column lookups

with sqlite3.connect('example.db') as conn:
    query = 'SELECT * FROM users'
    conn.row_factory = sqlite3.Row
    cursor = conn.cursor()
    cursor.execute(query)
    for row in cursor:
        print(row['username'], row['pto_days'])
    print(row.keys())

# %%
query = """
INSERT INTO users
VALUES
    (?, ?, ?, ?)"""

# %%
username = input('Enter username: ')
email = input('Enter email: ')
userid = input('Enter ID: ')
days = input('Enter PTO: ')

# %%
with sqlite3.connect('example.db') as conn:
    cursor = conn.cursor()
    cursor.execute(query, (userid, username, email, days))
    for row in cursor.execute('SELECT * from users'):
        print(row)

# %% [markdown]
# ## Bonus Lab:  DBAPI2
#
# Create your own sqlite3 database (HINT:  You can use the filename `:memory:` if you cannot create a file) and execute some SQL queries on it.  Try creating a table and adding a few rows, and then retrieving those rows.

# %% [markdown]
# ## More On Databases
#
# - Python has drivers for PostgreSQL, MySQL, MS-SQL, Oracle, and more!
# - Additional support for No-SQL databases, but they may not follow the DBAPI2 spec
# - If you need to do a LOT of database work, an ORM may help you - look at `sqlalchemy`
# - Database connectivity comes with a lot of gotchas!  Be especially careful when executing within loops.  There's often a better way!

# %% [markdown]
# ## Lab:  Astronomy API Client
# Look for the file **01_calling_apis_with_python.pdf** in your materials for instructions, and build your own standlone script that utilizes the Astronomy API at https://astronomyapi.com
